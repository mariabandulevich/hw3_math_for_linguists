# %% [markdown]
# Разработка системы транслитерации для немецкого языка.

# %%
conditions = {
    # начальное состояние автомата
    'q0': {
        'a': ('q1', ''),
        'b': ('q0', 'б'),
        'c': ('q2', ''),
        'd': ('q0', 'д'),
        'e': ('q3', ''),
        'f': ('q0', 'ф'),
        'g': ('q0', 'г'),
        'h': ('q0', 'х'),
        'i': ('q4', ''),
        'j': ('q0', 'й'),
        'k': ('q0', 'к'),
        'l': ('q0', 'л'),
        'm': ('q0', 'м'),
        'n': ('q0', 'н'),
        'o': ('q5', ''),
        'p': ('q6', ''),
        'q': ('q7', ''),
        'r': ('q0', 'р'),
        's': ('q8', ''),
        't': ('q9', ''),
        'u': ('q0', 'у'),
        'v': ('q0', 'ф'),
        'w': ('q0', 'в'),
        'x': ('q0', 'кс'),
        'y': ('q0', 'й'),
        'z': ('q0', 'ц'),
        'ä': ('q10', ''),
        'ö': ('q0', 'ё'),
        'ü': ('q0', 'ю'),
        'ß': ('q0', 'с'),
        ' ' : ('q0', ' ')
    },
    # состояние для a
    # новые состояния для тех букв, которые при сочетании с другими дают неочевидные сочетания
    'q1': {
        'a': ('q1', 'а'),
        'b': ('q0', 'аб'),
        'c': ('q2', 'а'),
        'd': ('q0', 'ад'),
        'e': ('q0', 'э'),
        'f': ('q0', 'аф'),
        'g': ('q0', 'аг'),
        'h': ('q0', 'а'),
        'i': ('q0', 'ай'),
        'j': ('q0', 'ай'),
        'k': ('q0', 'ак'),
        'l': ('q0', 'ал'),
        'm': ('q0', 'ам'),
        'n': ('q0', 'ан'),
        'o': ('q5', 'а'),
        'p': ('q6', 'а'),
        'q': ('q7', 'а'),
        'r': ('q0', 'ар'),
        's': ('q8', 'а'),
        't': ('q9', 'а'),
        'u': ('q0', 'ау'),
        'v': ('q0', 'аф'),
        'w': ('q0', 'ав'),
        'x': ('q0', 'акс'),
        'y': ('q0', 'ай'),
        'z': ('q0', 'ац'),
        'ä': ('q10', 'а'),
        'ö': ('q0', 'аё'),
        'ü': ('q0', 'аю'),
        'ß': ('q0', 'ас'),
        ' ' : ('q0', 'а ')
    },
    # состояние для c
    'q2': {
        'a': ('q1', 'к'),
        'b': ('q0', 'кб'),
        'c': ('q2', 'к'),
        'd': ('q0', 'кд'),
        'e': ('q3', 'к'),
        'f': ('q0', 'кф'),
        'g': ('q0', 'кг'),
        'h': ('q0', 'х'),
        'i': ('q4', 'к'),
        'j': ('q0', 'кй'),
        'k': ('q0', 'к'),
        'l': ('q0', 'кл'),
        'm': ('q0', 'км'),
        'n': ('q0', 'кн'),
        'o': ('q5', 'к'),
        'p': ('q6', 'к'),
        'q': ('q7', 'к'),
        'r': ('q0', 'кр'),
        's': ('q8', 'к'),
        't': ('q9', 'к'),
        'u': ('q0', 'ку'),
        'v': ('q0', 'кф'),
        'w': ('q0', 'кв'),
        'x': ('q0', 'кс'),
        'y': ('q0', 'ки'),
        'z': ('q0', 'кц'),
        'ä': ('q10', 'к'),
        'ö': ('q0', 'кё'),
        'ü': ('q0', 'кю'),
        'ß': ('q0', 'кс'),
        ' ' : ('q0', 'с ')
    },
    # состояние для e
    'q3': {
        'a': ('q1', 'е'),
        'b': ('q0', 'еб'),
        'c': ('q2', 'е'),
        'd': ('q0', 'ед'),
        'e': ('q3', 'е'),
        'f': ('q0', 'еф'),
        'g': ('q0', 'ег'),
        'h': ('q0', 'е'),
        'i': ('q0', 'ай'),
        'j': ('q0', 'ей'),
        'k': ('q0', 'ек'),
        'l': ('q0', 'ел'),
        'm': ('q0', 'ем'),
        'n': ('q0', 'ен'),
        'o': ('q5', 'е'),
        'p': ('q6', 'е'),
        'q': ('q7', 'е'),
        'r': ('q0', 'ер'),
        's': ('q8', 'е'),
        't': ('q9', 'е'),
        'u': ('q0', 'ой'),
        'v': ('q0', 'еф'),
        'w': ('q0', 'ев'),
        'x': ('q0', 'екс'),
        'y': ('q0', 'ай'),
        'z': ('q0', 'ец'),
        'ä': ('q10', 'е'),
        'ö': ('q0', 'её'),
        'ü': ('q0', 'ею'),
        'ß': ('q0', 'ес'),
        ' ' : ('q0', 'е ')
    },
    # состояние для i
    'q4': {
        'a': ('q1', 'и'),
        'b': ('q0', 'иб'),
        'c': ('q2', 'и'),
        'd': ('q0', 'ид'),
        'e': ('q0', 'и'),
        'f': ('q0', 'иф'),
        'g': ('q0', 'иг'),
        'h': ('q0', 'и'),
        'i': ('q4', 'и'),
        'j': ('q0', 'ий'),
        'k': ('q0', 'ик'),
        'l': ('q0', 'ил'),
        'm': ('q0', 'им'),
        'n': ('q0', 'ин'),
        'o': ('q5', 'и'),
        'p': ('q6', 'и'),
        'q': ('q7', 'и'),
        'r': ('q0', 'ир'),
        's': ('q8', 'и'),
        't': ('q9', 'и'),
        'u': ('q0', 'иу'),
        'v': ('q0', 'иф'),
        'w': ('q0', 'ив'),
        'x': ('q0', 'икс'),
        'y': ('q0', 'ий'),
        'z': ('q0', 'иц'),
        'ä': ('q10', 'и'),
        'ö': ('q0', 'иё'),
        'ü': ('q0', 'ию'),
        'ß': ('q0', 'ис'),
        ' ' : ('q0', 'и ')
    },
    # состояние для o
    'q5': {
        'a': ('q1', 'о'),
        'b': ('q0', 'об'),
        'c': ('q2', 'о'),
        'd': ('q0', 'од'),
        'e': ('q0', 'ё'),
        'f': ('q0', 'оф'),
        'g': ('q0', 'ог'),
        'h': ('q0', 'о'),
        'i': ('q0', 'ой'),
        'j': ('q0', 'ой'),
        'k': ('q0', 'ок'),
        'l': ('q0', 'ол'),
        'm': ('q0', 'ом'),
        'n': ('q0', 'он'),
        'o': ('q5', 'о'),
        'p': ('q6', 'о'),
        'q': ('q7', 'о'),
        'r': ('q0', 'ор'),
        's': ('q8', 'о'),
        't': ('q9', 'о'),
        'u': ('q0', 'оу'),
        'v': ('q0', 'оф'),
        'w': ('q0', 'ов'),
        'x': ('q0', 'окс'),
        'y': ('q0', 'ой'),
        'z': ('q0', 'оц'),
        'ä': ('q10', 'о'),
        'ö': ('q0', 'оё'),
        'ü': ('q0', 'ою'),
        'ß': ('q0', 'ос'),
        ' ' : ('q0', 'о ')
    },
    # состояние для p
    'q6': {
        'a': ('q1', 'п'),
        'b': ('q0', 'аб'),
        'c': ('q2', 'п'),
        'd': ('q0', 'пд'),
        'e': ('q0', 'пе'),
        'f': ('q0', 'пф'),
        'g': ('q0', 'пг'),
        'h': ('q0', 'ф'),
        'i': ('q4', 'п'),
        'j': ('q0', 'пй'),
        'k': ('q0', 'пк'),
        'l': ('q0', 'пл'),
        'm': ('q0', 'пм'),
        'n': ('q0', 'пн'),
        'o': ('q5', 'п'),
        'p': ('q6', 'п'),
        'q': ('q7', 'п'),
        'r': ('q0', 'пр'),
        's': ('q8', 'п'),
        't': ('q9', 'п'),
        'u': ('q0', 'пу'),
        'v': ('q0', 'пф'),
        'w': ('q0', 'пв'),
        'x': ('q0', 'пкс'),
        'y': ('q0', 'пи'),
        'z': ('q0', 'пц'),
        'ä': ('q10', 'п'),
        'ö': ('q0', 'пё'),
        'ü': ('q0', 'пю'),
        'ß': ('q0', 'пс'),
        ' ' : ('q0', 'п ')
    },
    # состояние для q
    'q7': {
        'a': ('q1', 'к'),
        'b': ('q0', 'кб'),
        'c': ('q2', 'к'),
        'd': ('q0', 'кд'),
        'e': ('q3', 'к'),
        'f': ('q0', 'кф'),
        'g': ('q0', 'кг'),
        'h': ('q0', 'к'),
        'i': ('q4', 'ки'),
        'j': ('q0', 'кй'),
        'k': ('q0', 'к'),
        'l': ('q0', 'кл'),
        'm': ('q0', 'км'),
        'n': ('q0', 'кн'),
        'o': ('q5', 'ко'),
        'p': ('q6', 'к'),
        'q': ('q7', 'к'),
        'r': ('q0', 'кр'),
        's': ('q8', 'к'),
        't': ('q9', 'к'),
        'u': ('q0', 'кв'),
        'v': ('q0', 'кф'),
        'w': ('q0', 'кв'),
        'x': ('q0', 'кс'),
        'y': ('q0', 'ки'),
        'z': ('q0', 'кц'),
        'ä': ('q10', 'к'),
        'ö': ('q0', 'кё'),
        'ü': ('q0', 'кю'),
        'ß': ('q0', 'кс'),
        ' ' : ('q0', 'к ')
    },
    # состояние для s
    'q8': {
        'a': ('q1', 'з'),
        'b': ('q0', 'зб'),
        'c': ('q11', ''),
        'd': ('q0', 'сд'),
        'e': ('q3', 'з'),
        'f': ('q0', 'зф'),
        'g': ('q0', 'зг'),
        'h': ('q0', 'зх'),
        'i': ('q4', 'з'),
        'j': ('q0', 'зй'),
        'k': ('q0', 'ск'),
        'l': ('q0', 'зл'),
        'm': ('q0', 'зм'),
        'n': ('q0', 'зн'),
        'o': ('q5', 'з'),
        'p': ('q0', 'шп'),
        'q': ('q7', 'з'),
        'r': ('q0', 'зр'),
        's': ('q8', 'с'),
        't': ('q0', 'шт'),
        'u': ('q0', 'зу'),
        'v': ('q0', 'зф'),
        'w': ('q0', 'зв'),
        'x': ('q0', 'зкс'),
        'y': ('q0', 'зи'),
        'z': ('q0', 'зц'),
        'ä': ('q10', 'з'),
        'ö': ('q0', 'зё'),
        'ü': ('q0', 'зю'),
        'ß': ('q0', 'с'),
        ' ' : ('q0', 'с ')
    },
    # состояние для t
    'q9': {
        'a': ('q1', 'т'),
        'b': ('q0', 'тб'),
        'c': ('q2', 'т'),
        'd': ('q0', 'тд'),
        'e': ('q3', 'т'),
        'f': ('q0', 'тф'),
        'g': ('q0', 'тг'),
        'h': ('q0', 'т'),
        'i': ('q12', ''),
        'j': ('q0', 'тй'),
        'k': ('q0', 'тк'),
        'l': ('q0', 'тл'),
        'm': ('q0', 'тм'),
        'n': ('q0', 'тн'),
        'o': ('q5', 'т'),
        'p': ('q6', 'тп'),
        'q': ('q7', 'т'),
        'r': ('q0', 'тр'),
        's': ('q8', 'тс'),
        't': ('q9', 'т'),
        'u': ('q0', 'ту'),
        'v': ('q0', 'тф'),
        'w': ('q0', 'тв'),
        'x': ('q0', 'ткс'),
        'y': ('q0', 'ти'),
        'z': ('q0', 'тц'),
        'ä': ('q10', 'т'),
        'ö': ('q0', 'тё'),
        'ü': ('q0', 'тю'),
        'ß': ('q0', 'тс'),
        ' ' : ('q0', 'т ')
    },
    # состояние для ä
    'q10': {
        'a': ('q1', 'э'),
        'b': ('q0', 'эб'),
        'c': ('q2', 'э'),
        'd': ('q0', 'эд'),
        'e': ('q3', 'э'),
        'f': ('q0', 'эф'),
        'g': ('q0', 'эг'),
        'h': ('q0', 'э'),
        'i': ('q4', 'э'),
        'j': ('q0', 'эй'),
        'k': ('q0', 'эк'),
        'l': ('q0', 'эл'),
        'm': ('q0', 'эм'),
        'n': ('q0', 'эн'),
        'o': ('q5', 'э'),
        'p': ('q6', 'э'),
        'q': ('q7', 'э'),
        'r': ('q0', 'эр'),
        's': ('q8', 'э'),
        't': ('q9', 'э'),
        'u': ('q0', 'ой'),
        'v': ('q0', 'эф'),
        'w': ('q0', 'эв'),
        'x': ('q0', 'экс'),
        'y': ('q0', 'эй'),
        'z': ('q0', 'эц'),
        'ä': ('q10', 'э'),
        'ö': ('q0', 'эё'),
        'ü': ('q0', 'эю'),
        'ß': ('q0', 'эс'),
        ' ' : ('q0', 'э ')
    },
    # состояние для sc
    'q11': {'h' : ('q0', 'ш')},
    # состояние для ti
    'q12' : {'o' : ("q0", "цио")}

}

# %%
import string

# определием начальное состояние автомата
start_state = 'q0'


# функция, которая возвращает следующее состояние и символ на основе текущего состояния и входного символа
def get_state(current_state, symbol):
    if current_state in conditions and symbol in conditions[current_state]:
        return conditions[current_state][symbol]
    return None, ''


# функция для транслитерации
def transliterate(input_text):
  current_state = start_state
  # список для транслитерированного текста
  transliterated_text = []

  # цикл для транслитерации
  for symbol in string_for_translit:
      # получаем новое состояние и символ для вывода
      current_state, to_print = get_state(current_state, symbol)
      # если символ не является пустым, то добавляем в список транслитерированного текста
      if to_print:
        transliterated_text.append(to_print)
  return ''.join(transliterated_text)


# обработка текста и работа программы
string_for_translit = input().lower()  # для примера можно взять предложение "Die Horde der rasenden Banditen: der Kampf für das Gute"
string_for_translit = string_for_translit.translate(str.maketrans('', '', string.punctuation))
print(transliterate(string_for_translit))
# Out:
# ди хорде дер разенден бандитен дер кампф фюр дас гут
